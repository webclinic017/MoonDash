# %%
##-- For Importing from Local Python Files
import sys

sys.path.insert(0, '../')
from core.backtest.backtest import Backtest
# Out:
# c:\python37\lib\site-packages\pyfolio\pos.py:27: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; mutltipliers will not be applied' +

# %%
Backtest()
# Out:
# Starting Portfolio Value: 20000.00
# 2020-01-11, BUY EXECUTED, Price: 8082.95, Cost: 8082.95, Comm 6.06
# 2020-01-20, SELL EXECUTED, Price: 8658.82, Cost: 8082.95, Comm 6.49
# 2020-01-26, BUY EXECUTED, Price: 8599.00, Cost: 8599.00, Comm 6.45
# 2020-02-02, SELL EXECUTED, Price: 9259.62, Cost: 8599.00, Comm 6.94
# 2020-02-02, BUY EXECUTED, Price: 9427.75, Cost: 9427.75, Comm 7.07
# 2020-02-03, SELL EXECUTED, Price: 9263.14, Cost: 9427.75, Comm 6.95
# 2020-02-05, BUY EXECUTED, Price: 9655.93, Cost: 9655.93, Comm 7.24
# 2020-02-11, SELL EXECUTED, Price: 9786.00, Cost: 9655.93, Comm 7.34
# 2020-02-11, BUY EXECUTED, Price: 10204.00, Cost: 10204.00, Comm 7.65
# 2020-02-15, SELL EXECUTED, Price: 9903.90, Cost: 10204.00, Comm 7.43
# 2020-02-19, BUY EXECUTED, Price: 10094.54, Cost: 10094.54, Comm 7.57
# 2020-02-20, SELL EXECUTED, Price: 9565.49, Cost: 10094.54, Comm 7.17
# 2020-02-23, BUY EXECUTED, Price: 9874.59, Cost: 9874.59, Comm 7.41
# ...
